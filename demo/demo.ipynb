# %%
# !pip install lark-parser
# Out:
# Requirement already satisfied: lark-parser in /home/agent/anaconda3/lib/python3.7/site-packages (0.7.0)

# %%
import sys
sys.path.append("../") # go to parent dir

# %%
import json
from src.Derivation import Derivation

# %%
evaluator = Derivation()

# %%
len(evaluator.rules)
# Out:
# 1409

# %%
print(evaluator.derive(word_b='снег', pos_b='noun', pos_a='noun'))
# Out:
# ['снегянка', 'суперснег', 'снеганин', 'ультраснег', 'снегеце', 'снегир', 'снегишка', 'снегура', 'снегышко', 'снгица', 'снегятина', 'снгист', 'снегина', 'снженка', 'снегия', 'снегиада', 'снегач', 'снегюшка', 'снегица', 'снегяга', 'снегат', 'снегонька', 'снегеныщ', 'экстраснег', 'снегизм', 'снегист', 'снгник', 'снегизация', 'снгизм', 'снегиана', 'экс-снег', 'расснег', 'обер-снег', 'снегоныш', 'снегянин', 'антиснег', 'снегятник', 'снегарь', 'снегушко', 'снежища', 'снегесса', 'снегушка', 'снегич', 'снегья', 'протоснег', 'снегенок', 'снгиха', 'снегинка', 'снежиха', 'дезснег', 'снегерия', 'снежица', 'снежонка', 'снегага', 'праснег', 'снеганка', 'неснег', 'снегища', 'снегник', 'снегование', 'снегенка', 'снегичка', 'снежоныш', 'снежишко', 'снегыня', 'снежонька', 'снежец', 'снегович', 'отснег', 'сверхснег', 'снгик', 'снегчик', 'снгенок', 'снегчонок', 'снегенция', 'снежина', 'снегня', 'снегик', 'снегок', 'снегечко', 'снгщик', 'снегиха', 'снегант', 'снеженька', 'снгина', 'снеженция', 'снегика', 'предснег', 'надснег', 'снегоид', 'снежинка', 'снжанка', 'снегчиха', 'снегин', 'паснег', 'архиснег', 'снежье', 'подснег', 'снегище', 'соснег', 'снегница', 'вице-снег', 'снежко', 'снегка', 'снежанин', 'переснег', 'снегаж', 'снгование', 'снежище', 'снегер', 'снегешка', 'снежик', 'снгеныщ', 'снегецо', 'субснег', 'снегчанин', 'реснег', 'снегко', 'снеговка', 'снегиня', 'снежушка', 'снегевание', 'снегщик', 'снегада', 'противоснег', 'снегевич', 'снегонок', 'деснег', 'снежатник', 'снежонок', 'снегыч', 'снежница', 'снегит', 'доснег', 'приснег', 'снегатура', 'снегяка', 'снеженка', 'снежишка', 'снежанка', 'снегье', 'снегец', 'дисснег', 'проснег', 'снегюшко', 'снегенька', 'снегатор', 'снегьевич', 'снегюга', 'снежок', 'снеговник', 'снежка', 'снгятник', 'снегиса', 'снгарь', 'снегация', 'снегор', 'снегевник', 'снегишко']

# %%
print(evaluator.derive(word_b='снег', pos_b='noun', pos_a='verb'))
# Out:
# ['расснгить', 'обесснежеть', 'отснгить', 'отснегить', 'наснежить', 'проснгить', 'обоснгить', 'обесснгить', 'обесснегить', 'обснгить', 'снегиться', 'заснегеть', 'приснежить', 'оснегиться', 'обснежеть', 'подоснегить', 'снегествовать', 'отоснежить', 'соснежить', 'снежиться', 'снегевать', 'обесснегеть', 'обснегеть', 'обесснгеть', 'обоснегиться', 'обоснежеть', 'проснежить', 'приснгить', 'подснежить', 'обснгеть', 'исснежить', 'оснежиться', 'оснгить', 'обснежиться', 'подснегить', 'снежить', 'подоснежить', 'уснежить', 'приснегить', 'снегировать', 'обснегить', 'отснежить', 'поснгить', 'обснгиться', 'отоснгить', 'наснгить', 'заснгеть', 'снегствовать', 'наснегить', 'снеговать', 'обснегиться', 'обесснежить', 'снгиться', 'обснежить', 'подснгить', 'обоснгиться', 'оснежить', 'соснегить', 'уснгить', 'подоснгить', 'исснегить', 'заснежеть', 'заснгить', 'снегизовать', 'проснегить', 'сснегить', 'оснегить', 'переснегить', 'поснегить', 'расснегить', 'поснежить', 'переснежить', 'исснгить', 'расснежить', 'сснгить', 'обоснегить', 'обоснежить', 'снегничать', 'заснежить', 'обоснегеть', 'снежествовать', 'оснгиться', 'уснегить', 'переснгить', 'обоснежиться', 'снегить', 'сснежить', 'обоснгеть', 'соснгить', 'отоснегить', 'снегизировать', 'заснегить', 'снгить']

# %%
print(evaluator.derive(word_b='снег', pos_b='noun'))
# Out:
# ['отснегной', 'снегянка', 'обесснежеть', 'снегевский', 'отснегить', 'проснгить', 'заснегованный', 'снегина', 'снженка', 'обесснегить', 'заснегеванный', 'приснежить', 'оснегиться', 'снегозный', 'соснежить', 'снежиться', 'снгник', 'снегизация', 'междуснежский', 'снгизм', 'снегиана', 'снегов', 'обер-снег', 'обоснегиться', 'поснегной', 'снегоныш', 'проснежить', 'снегятник', 'снегарь', 'поснежский', 'исснежить', 'поснежной', 'снегья', 'снгевый', 'снегенок', 'снегеский', 'межснежный', 'снегинка', 'снежить', 'снеганка', 'снегища', 'подснежной', 'подоснежить', 'приснегить', 'обснегить', 'снгенок', 'наснегить', 'отснежной', 'снегок', 'обснежить', 'предснег', 'снеговый', 'снегоид', 'снегеватый', 'паснег', 'надснегный', 'снегище', 'исснегить', 'внеснегный', 'межснежной', 'надснегной', 'снегизовать', 'снеговский', 'оснегить', 'снгеныщ', 'переснегить', 'межснегкий', 'внеснегкий', 'расснегить', 'снгевой', 'неснегный', 'расснежить', 'снегевич', 'снежный', 'снегыч', 'снежница', 'приснег', 'снегический', 'снеженка', 'снежишка', 'снежчатый', 'внутриснежской', 'снегатор', 'снежествовать', 'внеснегский', 'снеговник', 'приснежской', 'снегить', 'снгарь', 'снегю', 'внутриснегкий', 'приснежный', 'заснегский', 'снегишко', 'снгить', 'отснгить', 'снеганин', 'снгов', 'межснегский', 'снговитый', 'наснегный', 'обесснгить', 'внеснежной', 'обснгить', 'снегюшка', 'снегица', 'надснежной', 'подснегный', 'снегяга', 'обснежеть', 'снегист', 'внутриснегский', 'приснежной', 'внутриснежный', 'обснегеть', 'поснегкий', 'поснегный', 'обесснгеть', 'воснег', 'снеговской', 'околоснегной', 'снегом', 'снегной', 'предснегной', 'снегятый', 'снегушко', 'оснгить', 'снежища', 'междуснегский', 'обснежиться', 'вснег', 'подснегить', 'снегевской', 'межснегной', 'околоснегный', 'снегование', 'снегичка', 'заснегный', 'межснежской', 'снегыня', 'околоснежный', 'снегировать', 'снежонька', 'снегичный', 'внеснежской', 'поснгить', 'обснгиться', 'отснег', 'сверхснег', 'междуснежной', 'снжоватый', 'приснежский', 'снегня', 'снеговать', 'снгщик', 'обесснежить', 'снгиться', 'снегиха', 'снеженция', 'снежинка', 'архиснег', 'снеговой', 'уснгить', 'соснег', 'вице-снег', 'заснежеть', 'подснежный', 'снежко', 'околоснежной', 'снегаж', 'снегарный', 'поснежный', 'субснег', 'снегчанин', 'снеговка', 'снегиня', 'снегада', 'переснежить', 'противоснег', 'снежатник', 'снежонок', 'снегит', 'снегяка', 'заснегной', 'снегничать', 'снежанка', 'обоснегеть', 'снегенька', 'междуснежской', 'заснегенный', 'переснгить', 'снежка', 'снегация', 'снегор', 'снегский', 'снегевник', 'отоснегить', 'расснгить', 'поснежской', 'суперснег', 'снговой', 'снегышко', 'подснегной', 'наснегной', 'заснежский', 'неснежной', 'снегач', 'снеговитый', 'снегчатый', 'бесснежной', 'снегонька', 'внутриснегной', 'экстраснег', 'снегизм', 'снегевой', 'снегествовать', 'снегястый', 'обесснегеть', 'экс-снег', 'поснегский', 'снегянин', 'антиснег', 'снегатый', 'приснгить', 'подснежить', 'обснгеть', 'снегесса', 'снегушка', 'внутриснежский', 'дезснег', 'приснегный', 'снежица', 'снегерия', 'снегской', 'праснег', 'снегник', 'снегенка', 'снговский', 'снежоныш', 'снегкий', 'снежишко', 'приснегкий', 'снежец', 'междуснежный', 'отоснгить', 'наснгить', 'снегчонок', 'снежина', 'внеснежский', 'снгом', 'снегант', 'снеженька', 'снегика', 'снеговатый', 'снегастый', 'снговатый', 'междуснегкий', 'заснежный', 'наснегенный', 'снежье', 'подснег', 'соснегить', 'снегка', 'переснег', 'сснегить', 'снгование', 'наснег', 'снежик', 'снегешка', 'реснег', 'снегко', 'снежий', 'неснежный', 'снегевый', 'снегонок', 'доснег', 'предснегный', 'снегатура', 'бесснегый', 'заснежить', 'снегец', 'дисснег', 'междуснегный', 'снегьевич', 'снегюга', 'оснгиться', 'уснегить', 'обоснежиться', 'снгятник', 'сснежить', 'соснгить', 'снежливый', 'снежной', 'снговый', 'ультраснег', 'снегеце', 'снегир', 'снегевитый', 'наснежить', 'снегивый', 'снегура', 'снегишка', 'бесснегий', 'снгица', 'обоснгить', 'снегятина', 'снгист', 'неснегной', 'снжовитый', 'отснегный', 'снегия', 'снегиться', 'заснегеть', 'снегиада', 'сн ...

# %%
print(evaluator.derive(word_b='водить', pos_b='verb', pos_a='adv'))
# Out:
# ['ввод', 'наводь', 'водмя', 'водиючи', 'навожь', 'ввож', 'навож', 'ввожь', 'водивмя', 'навод', 'вводь']

# %%
print(evaluator.derive(word_b='водить', pos_b='verb', pos_a='adj'))
# Out:
# ['водимый', 'водительный', 'водной', 'водильный', 'завожденный', 'заводинный', 'водитый', 'водкий', 'водьючий', 'водиючий', 'водный', 'безводный', 'неводимый', 'безводной', 'водивучий', 'неводной', 'завоженный', 'водилой', 'неводный', 'водистый', 'вожденный', 'водиемый', 'водительский', 'водинный', 'вожливый', 'водилый', 'неводиемый', 'водливый', 'водячий', 'воженный', 'воженый']

# %%
print(evaluator.derive(word_b='водить', pos_b='verb', pos_a='verb'))
# Out:
# ['разводить', 'приводиться', 'соводиьнуться', 'поводать', 'соводиьнуть', 'вонуть', 'отоводиться', 'своднуть', 'вводиться', 'разводывать', 'свонуть', 'вводить', 'подоводить', 'водинуться', 'уводиться', 'взводнуть', 'уводить', 'изоводить', 'приводить', 'переводить', 'возводить', 'низоводить', 'подводить', 'водануть', 'привонуть', 'наводывать', 'выводить', 'разоводиться', 'поводивать', 'взводиьнуться', 'сводинуть', 'разоводывать', 'водивать', 'приводать', 'разводиться', 'наводивать', 'приводиьнуться', 'деводить', 'отводивать', 'доводить', 'приводивать', 'подоводывать', 'отоводать', 'недоводить', 'выводать', 'совонуть', 'проводить', 'изводиться', 'обводиться', 'переводать', 'взводиьнуть', 'сводиьнуть', 'подоводать', 'водинуть', 'соводиться', 'взоводиьнуть', 'отоводивать', 'водивануть', 'переводывать', 'безоводить', 'обводить', 'взоводиться', 'сводиьнуться', 'разоводать', 'взводинуть', 'взовонуть', 'водиьнуться', 'соводнуть', 'оводиться', 'взоводиьнуться', 'разводать', 'выводывать', 'преводить', 'дисводить', 'водиться', 'разоводить', 'выводиться', 'соводинуться', 'подоводиться', 'подоводивать', 'подводивать', 'отоводывать', 'надоводить', 'подводиться', 'отводиться', 'предоводить', 'соводинуть', 'приводинуться', 'заводить', 'дезводить', 'наводать', 'выводивать', 'изоводиться', 'предводить', 'отводывать', 'взоводинуться', 'подводать', 'взводить', 'обоводить', 'реводить', 'взоводить', 'проводиться', 'доводиться', 'разводивать', 'надводить', 'взоводнуть', 'возоводить', 'наводиться', 'заводиться', 'низводить', 'приводывать', 'воводить', 'отводить', 'отоводить', 'сводиться', 'взоводинуть', 'водать', 'изводить', 'водиьнуть', 'взводиться', 'отводать', 'разоводивать', 'приводинуть', 'взвонуть', 'соводить', 'приводиьнуть', 'безводить', 'приводнуть', 'обоводиться', 'переводивать', 'оводить', 'взводинуться', 'сводить', 'подводывать', 'сводинуться', 'воднуть', 'поводить', 'поводывать', 'воводиться', 'водывать', 'наводить']

# %%
print(evaluator.derive(word_b='водить', pos_b='verb', pos_a='noun'))
# Out:
# ['водство', 'водинье', 'водитье', 'водок', 'водяга', 'водиилка', 'водиемость', 'водь', 'водьюн', 'водиуха', 'водимость', 'воденье', 'водилец', 'водор', 'водя', 'водильщик', 'водоина', 'водиенье', 'вождение', 'водиток', 'водиловка', 'водиянье', 'водиитель', 'водищик', 'водитель', 'водня', 'водика', 'водыш', 'водиня', 'водичик', 'водля', 'вожина', 'водиша', 'водияние', 'водач', 'водание', 'водиильщик', 'водильня', 'вода', 'водоёк', 'водиво', 'водило', 'водива', 'водинность', 'водить', 'води', 'вождество', 'водила', 'водша', 'водовка', 'водер', 'водушка', 'водёж', 'водевка', 'водивун', 'водение', 'водежка', 'водильник', 'водот', 'водака', 'водево', 'водиние', 'воженье', 'водина', 'воденность', 'водун', 'водуха', 'водие', 'водилка', 'водитево', 'вожение', 'водуемость', 'водки', 'водой', 'водье', 'водишка', 'водиха', 'водщик', 'вод', 'воданье', 'водов', 'водка', 'водинь', 'водчик', 'водиение', 'водитие', 'водительство']

# %%
print(evaluator.derive_ext(word_b='водить', pos_b='verb', pos_a='noun'))
# Out:
# [('водило', 'rule230(л):1'), ('водор', 'rule225(ор):1'), ('водой', 'rule446(0m2):2'), ('водива', 'rule451(0f1):2'), ('водиуха', 'rule279(ух):2'), ('водка', 'rule231(к):1'), ('водиилка', 'rule228(лк):3'), ('водоина', 'rule248(ин):3'), ('водильня', 'rule241(льн):1'), ('вода', 'rule451(0f1):1'), ('воденность', 'rule253(нность):3'), ('водня', 'rule267(ня):1'), ('водьюн', 'rule220(ун):2'), ('водиние', 'rule256(ние):1'), ('водиловка', 'rule229(ловк):1'), ('водинность', 'rule253(нность):2'), ('водиенье', 'rule256(енье):4'), ('водание', 'rule256(ание):3'), ('водиение', 'rule256(ение):5'), ('водер', 'rule225(ор):1'), ('водежка', 'rule262(ежк):1'), ('водь', 'rule454(0f3):1'), ('водина', 'rule248(ин):1'), ('водуха', 'rule234(ух):1'), ('водя', 'rule451(0f1):1'), ('водиильщик', 'rule214(льщик):3'), ('водиток', 'rule221(ок):3'), ('водитье', 'rule256(тье):1'), ('водля', 'rule237(ул):1'), ('водок', 'rule270(ок):1'), ('водовка', 'rule262(овк):1'), ('водач', 'rule219(ач):1'), ('водительство', 'rule264(тельств):1'), ('водиилка', 'rule230(л):3'), ('водушка', 'rule231(ушк):1'), ('водение', 'rule256(ение):1'), ('водие', 'rule256(ие):1'), ('водитево', 'rule249(ин):3'), ('водство', 'rule264(ств):1'), ('воданье', 'rule256(анье):3'), ('водуемость', 'rule252(имость):2'), ('водиха', 'rule279(ух):3'), ('водша', 'rule236(уш):1'), ('водильник', 'rule215(льник):1'), ('водить', 'rule454(0f3):2'), ('водика', 'rule261(к):3'), ('водитель', 'rule211(тель):1'), ('водок', 'rule221(ок):1'), ('водыш', 'rule247(ыш):1'), ('водиха', 'rule234(ух):1'), ('водиво', 'rule249(ин):1'), ('вожение', 'rule256(ение):2'), ('воженье', 'rule256(енье):1'), ('водивун', 'rule220(ун):3'), ('водияние', 'rule256(ание):1'), ('водиянье', 'rule256(анье):1'), ('водищик', 'rule213(щик):1'), ('водение', 'rule256(ение):2'), ('вожина', 'rule248(ин):1'), ('вождество', 'rule264(еств):1'), ('водевка', 'rule262(овк):1'), ('водинь', 'rule454(0f3):4'), ('вод', 'rule446(0m2):1'), ('водилец', 'rule217(лец):1'), ('водиня', 'rule267(ня):2'), ('водоёк', 'rule221(ок):2'), ('водка', 'rule261(к):1'), ('водичик', 'rule213(щик):1'), ('водитие', 'rule256(тие):1'), ('водщик', 'rule213(щик):1'), ('водёж', 'rule269(ёж):1'), ('водиемость', 'rule252(имость):1'), ('водов', 'rule446(0m2):3'), ('водчик', 'rule213(щик):1'), ('водот', 'rule278(от):1'), ('водинье', 'rule256(нье):1'), ('водье', 'rule256(ье):1'), ('водиша', 'rule236(ш):1'), ('водинность', 'rule253(нность):1'), ('водила', 'rule230(л):1'), ('воденье', 'rule256(енье):1'), ('водево', 'rule249(ин):5'), ('водун', 'rule220(ун):1'), ('водуха', 'rule279(ух):1'), ('водильщик', 'rule214(льщик):1'), ('водиитель', 'rule211(тель):2'), ('водака', 'rule233(ак):1'), ('водяга', 'rule232(аг):1'), ('водиитель', 'rule212(ник):2'), ('водишка', 'rule231(шк):1'), ('водимость', 'rule252(имость):3'), ('водки', 'rule250(к):1'), ('вожение', 'rule256(ение):1'), ('вождение', 'rule256(ение):2'), ('водилка', 'rule228(лк):1'), ('води', 'rule446(0m2):4')]

# %%
print(evaluator.derive_ext(word_b='красный', pos_b='adj', pos_a='verb'))
# Out:
# [('закраснить', 'rule888(за,и):2'), ('окраснить', 'rule888(за,и):2'), ('украснить', 'rule902(у,и):2'), ('прокраснить', 'rule899(про,и):2'), ('краснничать', 'rule814(нича):1'), ('отокраснить', 'rule894(от,и):2'), ('обкраснить', 'rule888(за,и):2'), ('подокраснить', 'rule896(по,и):1'), ('перекраснить', 'rule895(пере,и):1'), ('отокраснить', 'rule894(от,и):1'), ('подкраснить', 'rule896(по,и):2'), ('скраснить', 'rule899(про,и):2'), ('краснить', 'rule796(и):2'), ('краснничать', 'rule814(нича):2'), ('краснеть', 'rule830(е):3'), ('сокраснить', 'rule899(про,и):2'), ('украснить', 'rule902(у,и):1'), ('обескраснить', 'rule893(обез,и):2'), ('откраснить', 'rule894(от,и):1'), ('перекраснить', 'rule895(пере,и):2'), ('подокраснить', 'rule896(по,и):2'), ('обескраснить', 'rule893(обез,и):1'), ('раскраснить', 'rule900(раз,и):2'), ('покраснить', 'rule896(по,и):1'), ('краснить', 'rule796(и):1'), ('раскраснить', 'rule900(раз,и):1'), ('обокраснить', 'rule888(за,и):2'), ('окраснеть', 'rule905(о,е):2'), ('красовать', 'rule807(ова):1'), ('скраснить', 'rule899(про,и):1'), ('покраснеть', 'rule908(о,е):1'), ('накраснить', 'rule888(за,и):2'), ('сокраснить', 'rule899(про,и):1'), ('красеть', 'rule830(е):1'), ('покраснеть', 'rule908(о,е):2'), ('закраснеть', 'rule904(за,е):1'), ('краснеть', 'rule830(е):1'), ('красствовать', 'rule817(ствова):1'), ('откраснить', 'rule894(от,и):2'), ('прикраснить', 'rule898(при,и):1'), ('подкраснить', 'rule896(по,и):1'), ('искраснить', 'rule889(из,и):1'), ('окраснеть', 'rule905(о,е):1'), ('красниться', 'rule933(и,ся):1'), ('покраснить', 'rule896(по,и):2'), ('прикраснить', 'rule898(при,и):2'), ('красеть', 'rule830(е):2'), ('накраснить', 'rule888(за,и):1'), ('закраснить', 'rule888(за,и):1'), ('окраснить', 'rule888(за,и):1'), ('прокраснить', 'rule899(про,и):1'), ('закраснеть', 'rule904(за,е):2'), ('искраснить', 'rule889(из,и):2'), ('обокраснить', 'rule888(за,и):1'), ('красновать', 'rule807(ова):1'), ('обкраснить', 'rule888(за,и):1'), ('красновать', 'rule807(ова):2'), ('красниться', 'rule933(и,ся):2')]

# %%
print(evaluator.derive(word_b='красный', pos_b='adj', pos_a='verb'))
# Out:
# ['красовать', 'прикраснить', 'красниться', 'искраснить', 'обескраснить', 'покраснить', 'сокраснить', 'красновать', 'покраснеть', 'перекраснить', 'красствовать', 'закраснеть', 'обкраснить', 'украснить', 'краснеть', 'подкраснить', 'закраснить', 'откраснить', 'подокраснить', 'обокраснить', 'накраснить', 'скраснить', 'раскраснить', 'отокраснить', 'краснничать', 'окраснеть', 'краснить', 'красеть', 'прокраснить', 'окраснить']
